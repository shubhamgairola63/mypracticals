# %%
import ee, geemap
ee.Authenticate(auth_mode='colab')
ee.Initialize(project='adv-python-practicals-255601')

# Create map
Map = geemap.Map(center=[19.0, 72.9], zoom=11)

# Define ROI for Mumbai (ensure lon/lat order: [west, south, east, north])
roi_mumbai = ee.Geometry.Rectangle([72.7, 18.8, 73.0, 19.3])

# Add ROI to map
Map.addLayer(roi_mumbai, {'color': 'red'}, 'ROI Mumbai')

# Select a single Sentinel-2 image that intersects ROI
img = (
    ee.ImageCollection('COPERNICUS/S2_SR')
    .filterDate('2025-01-15', '2025-02-15')
    .filterBounds(roi_mumbai)
    .sort('CLOUDY_PIXEL_PERCENTAGE')
    .first()
)

# Clip image to ROI so it doesn't go beyond
img_clipped = img.clip(roi_mumbai)

# Add clipped RGB (True color) to map
Map.addLayer(
    img_clipped,
    {'bands': ['B4', 'B3', 'B2'], 'min': 0, 'max': 3000},
    'S2 RGB clipped'
)

# Compute NDVI and add clipped NDVI layer
ndvi = img_clipped.normalizedDifference(['B8', 'B4']).rename('NDVI')
ndvi_vis = {'min': 0, 'max': 1, 'palette': ['white', 'lightgreen', 'green']}
Map.addLayer(ndvi, ndvi_vis, 'NDVI clipped')

Map.centerObject(roi_mumbai, 11)
Map
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 import ee, geemap
# ----> 2 ee.Authenticate(auth_mode='colab')
#       3 ee.Initialize(project='adv-python-practicals-255601')
#       5 # Create map
#
# File c:\Users\SHISHPAL\AppData\Local\Programs\Python\Python313\Lib\site-packages\ee\__init__.py:201, in Authenticate(authorization_code, quiet, code_verifier, auth_mode, scopes, force)
#     170 def Authenticate(
#     171     authorization_code: str | None = None,
#     172     quiet: bool | None = None,
#    (...)
#     176     force: bool = False,
#     177 ) -> bool | None:
#     178   """Prompts the user to authorize access to Earth Engine via OAuth2.
#     179
#     180   Args:
#    (...)
#     199     True if we found valid credentials and didn't run the auth flow.
#     200   """
# --> 201   return oauth.authenticate(authorization_code, quiet, code_verifier, auth_mode,
#     202                             scopes, force)
#
# File c:\Users\SHISHPAL\AppData\Local\Programs\Python\Python313\Lib\site-packages\ee\oauth.py:546, in authenticate(cli_authorization_code, quiet, cli_code_verifier, auth_mode, scopes, force)
#     543   return
#     545 if auth_mode == 'colab':
# --> 546   from google.colab import auth  # pylint: disable=g-import-not-at-top # pytype: disable=import-error
#     547   auth.authenticate_user()
#     548   return
#
# ModuleNotFoundError: No module named 'google.colab'
